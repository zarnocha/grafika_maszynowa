# %%
from PIL import Image
import numpy as np
from PIL import ImageChops
import matplotlib.pyplot as plt
from PIL import ImageStat as stat

# %%
obraz1 = Image.open('obraz1.png')
print(f'Tryb obrazu: {obraz1.mode}')
obraz1
# Out:
# Tryb obrazu: RGBA
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x800>

# %%
obraz2 = obraz1.convert("RGB")
print(f'Tryb obrazu: {obraz2.mode}')
obraz2
# Out:
# Tryb obrazu: RGB
# <PIL.Image.Image image mode=RGB size=800x800>

# %%
r, g, b, a = obraz1.split()

obraz3 = Image.new('RGB', obraz1.size, (255,255,255))
obraz3.paste(obraz1, (0, 0), a)
print(f'Tryb obrazu: {obraz3.mode}')
obraz3.save("obraz3.png")
obraz3
# Out:
# Tryb obrazu: RGB
# <PIL.Image.Image image mode=RGB size=800x800>

# %%
a
# Out:
# <PIL.Image.Image image mode=L size=800x800>

# %%
roznica = ImageChops.difference(obraz2, obraz3)
roznica.save("roznica_obraz2_obraz3.jpg")
roznica
# Out:
# <PIL.Image.Image image mode=RGB size=800x800>
